# %%
from collections import Counter

# %%
import json
with open("../data/drug-event-0030-of-0030.json") as f:
    data = json.load(f)

# %%
data = data['results']

# %%
len(data)
# Out:
# 8210

# %%
medicinalproducts =[]

for drugs in data:
    for drug in drugs['patient']['drug']:
        medicinalproducts.append(drug['medicinalproduct'])

# %%
c = Counter(medicinalproducts)
c.most_common()
# Out:
# [('MOUNJARO', 1556),
#  ('METHOTREXATE', 716),
#  ('REPATHA', 637),
#  ('INFLECTRA', 555),
#  ('PREDNISONE', 544),
#  ('ACETAMINOPHEN', 541),
#  ('ASPIRIN', 497),
#  ('RITUXIMAB', 389),
#  ('DUPIXENT', 385),
#  ('DEXAMETHASONE', 363),
#  ('VEDOLIZUMAB', 334),
#  ('OMEPRAZOLE', 317),
#  ('ATORVASTATIN', 304),
#  ('PAXLOVID', 286),
#  ('RISPERDAL', 283),
#  ('CYCLOPHOSPHAMIDE', 279),
#  ('GABAPENTIN', 278),
#  ('FOLIC ACID', 276),
#  ('ELIGARD', 269),
#  ('COSENTYX', 256),
#  ('TEDUGLUTIDE', 249),
#  ('FUROSEMIDE', 247),
#  ('PREDNISOLONE', 238),
#  ('ALBUTEROL SULFATE', 236),
#  ('PANTOPRAZOLE', 222),
#  ('VITAMIN D3', 218),
#  ('TACROLIMUS', 217),
#  ('AMLODIPINE', 214),
#  ('LENALIDOMIDE', 213),
#  ('HUMIRA', 203),
#  ('METFORMIN', 198),
#  ('ACTEMRA', 198),
#  ('KEYTRUDA', 196),
#  ('IBUPROFEN', 195),
#  ('ADALIMUMAB', 190),
#  ('CARBOPLATIN', 189),
#  ('LORAZEPAM', 188),
#  ('CLOZAPINE', 186),
#  ('ALBUTEROL', 185),
#  ('ORENCIA', 182),
#  ('ROSUVASTATIN', 174),
# ...

# %%
drugs['patient']
# Out:
# {'reaction': [{'reactionmeddraversionpt': '26.1',
#    'reactionmeddrapt': 'Thrombosis',
#    'reactionoutcome': '6'}],
#  'drug': [{'drugcharacterization': '1',
#    'medicinalproduct': 'LOSARTAN POTASSIUM',
#    'drugbatchnumb': 'Unknown',
#    'drugauthorizationnumb': '078232',
#    'drugstructuredosagenumb': '50',
#    'drugstructuredosageunit': '003',
#    'drugseparatedosagenumb': '2',
#    'drugintervaldosageunitnumb': '1',
#    'drugintervaldosagedefinition': '804',
#    'drugdosagetext': '50 MILLIGRAM, BID, TAKE 1 TABLE TWICE DAILY',
#    'drugdosageform': 'Tablet',
#    'drugadministrationroute': '048',
#    'drugindication': 'Hypertension',
#    'actiondrug': '5',
#    'drugadditional': '3',
#    'activesubstance': {'activesubstancename': 'LOSARTAN POTASSIUM'},
#    'openfda': {'application_number': ['ANDA091541',
#      'ANDA217396',
#      'ANDA078243',
#      'ANDA090428',
#      'ANDA203835',
#      'ANDA090083',
#      'NDA020386',
#      'ANDA090382',
# ...
